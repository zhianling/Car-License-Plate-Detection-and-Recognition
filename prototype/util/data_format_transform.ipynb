# %% [markdown]
# # Configuration

# %% [markdown]
# ## Import packages

# %%
import cv2
import os
import xml.etree.ElementTree as ET
import json
import math
import concurrent.futures

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Extract frames from CVAT annotation

# %%
def process_frame(frame_count, frame, annotated_frames, frame_subdir):
    """
    Processes a single frame: saves it if it's annotated.  This function
    is designed to be run in a separate thread.

    Args:
        frame_count (int): The frame number.
        frame (numpy.ndarray): The frame data (image).
        annotated_frames (set): Set of annotated frame numbers.
        frame_subdir (str): Path to the subdirectory to save frames.
    """
    if frame_count in annotated_frames:
        frame_filename = f"frame{frame_count:05d}.jpg"
        frame_path = os.path.join(frame_subdir, frame_filename)
        cv2.imwrite(frame_path, frame)

def convert_video_to_frames(video_dir, frame_dir, annotation_dir):
    """
    Converts video files to individual frames, saving them to the specified
    directory. Skips frames that are not annotated in the corresponding CVAT
    XML file. Uses multithreading to speed up the process.

    Args:
        video_dir (str): Path to the directory containing video files.
        frame_dir (str): Path to the directory where frames will be saved.
        annotation_dir (str): Path to the directory containing CVAT XML
            annotations.
    """

    for video_file in os.listdir(video_dir):
        if video_file.endswith(".mp4"):  # Or other video extensions
            video_path = os.path.join(video_dir, video_file)
            video_name = os.path.splitext(video_file)[0]
            frame_subdir = os.path.join(frame_dir, video_name)

            # Check if the frames for this video have already been extracted
            if os.path.exists(frame_subdir) and len(os.listdir(frame_subdir)) > 0:
                print(f"Frames for {video_file} already extracted. Skipping.")
                continue

            os.makedirs(frame_subdir, exist_ok=True)

            # Find corresponding annotation file
            annotation_file = f"annotation_{video_name.replace('video', 'cvat')}.xml"
            annotation_path = os.path.join(annotation_dir, annotation_file)

            if not os.path.exists(annotation_path):
                print(f"Annotation file not found for {video_file}. Skipping.")
                continue

            # Parse annotation file to get annotated frame numbers
            tree = ET.parse(annotation_path)
            root = tree.getroot()
            annotated_frames = set()
            for track in root.findall(".//track"):
                for box in track.findall(".//box"):
                    annotated_frames.add(int(box.get("frame")))

            cap = cv2.VideoCapture(video_path)
            frame_count = 0

            with concurrent.futures.ThreadPoolExecutor() as executor:
                futures = []
                while True:
                    ret, frame = cap.read()
                    if not ret:
                        break

                    # Submit the frame processing to the thread pool
                    future = executor.submit(process_frame, frame_count, frame, annotated_frames, frame_subdir)
                    futures.append(future)

                    frame_count += 1

                # Wait for all frame processing tasks to complete
                for future in concurrent.futures.as_completed(futures):
                    try:
                        future.result()  # Get the result (or exception)
                    except Exception as e:
                        print(f"Error processing frame: {e}")

            cap.release()
            print(f"Frames extracted from {video_file} to {frame_subdir}")

# %% [markdown]
# ## Create COCO JSON from CVAT annotation and extracted frames

# %%
def rotate_point(x, y, angle, width, height):
    """
    Rotate a point (x, y) by a given angle (in degrees) around the center of an image.

    Args:
        x (float): X-coordinate of the point.
        y (float): Y-coordinate of the point.
        angle (float): Rotation angle in degrees.
        width (int): Width of the image.
        height (int): Height of the image.

    Returns:
        tuple: Rotated (x, y) coordinates.
    """
    # Convert angle to radians
    rad = math.radians(angle)
    # Translate point to origin
    x -= width / 2
    y -= height / 2
    # Rotate point
    rotated_x = x * math.cos(rad) - y * math.sin(rad)
    rotated_y = x * math.sin(rad) + y * math.cos(rad)
    # Translate point back to original position
    rotated_x += width / 2
    rotated_y += height / 2
    return rotated_x, rotated_y

def convert_cvat_to_coco(cvat_dir, coco_dir):
    """
    Converts CVAT XML annotations to COCO JSON format.  Creates subdirectories
    in the COCO directory for each CVAT XML file.

    Args:
        cvat_dir (str): Path to the directory containing CVAT XML annotations.
        coco_dir (str): Path to the directory where COCO JSON files will be saved.
    """
    os.makedirs(coco_dir, exist_ok=True)

    for cvat_file in os.listdir(cvat_dir):
        if not cvat_file.endswith(".xml"):
            continue

        cvat_path = os.path.join(cvat_dir, cvat_file)
        tree = ET.parse(cvat_path)
        root = tree.getroot()

        # Extract image width and height from CVAT metadata
        width = int(root.find(".//original_size/width").text)
        height = int(root.find(".//original_size/height").text)

        # Get label names
        labels = []
        for label in root.findall(".//label/name"):
            labels.append(label.text)

        # Create a dictionary to store COCO data for each frame
        coco_data_per_frame = {}

        # --- Create subdirectory for this CVAT file ---
        cvat_name = os.path.splitext(cvat_file)[0]
        coco_subdir = os.path.join(coco_dir, cvat_name)
        os.makedirs(coco_subdir, exist_ok=True)  # Create the subdirectory


        # Process annotations for each track
        for track in root.findall(".//track"):
            label = track.get("label")
            label_id = labels.index(label) + 1  # COCO category IDs start from 1

            for box in track.findall(".//box"):
                frame_num = int(box.get("frame"))
                xtl = float(box.get("xtl"))
                ytl = float(box.get("ytl"))
                xbr = float(box.get("xbr"))
                ybr = float(box.get("ybr"))
                rotation = float(box.get("rotation", 0.0))  # Default to 0 if not present

                # Rotate bounding box coordinates
                if rotation != 0:
                    center_x = (xtl + xbr) / 2
                    center_y = (ytl + ybr) / 2

                    xtl, ytl = rotate_point(xtl, ytl, rotation, width, height)
                    xbr, ybr = rotate_point(xbr, ybr, rotation, width, height)
                    center_x, center_y = rotate_point(center_x, center_y, rotation, width, height)

                    # Recalculate xtl, ytl, xbr, ybr based on rotated center and dimensions
                    width_box = abs(xbr - xtl)
                    height_box = abs(ybr- ytl)
                    xtl = center_x - width_box / 2
                    ytl = center_y - height_box / 2
                    xbr = center_x + width_box / 2
                    ybr = center_y + height_box / 2

                # Calculate bounding box width and height
                bbox_width = xbr - xtl
                bbox_height = ybr - ytl

                # Get attributes
                attributes = {}
                for attribute in box.findall(".//attribute"):
                    attributes[attribute.get("name")] = attribute.text

                # Prepare COCO data for this frame (if not already created)
                if frame_num not in coco_data_per_frame:
                    coco_data_per_frame[frame_num] = {
                        "info": {},
                        "licenses": [],
                        "categories": [{"id": i + 1, "name": label, "supercategory": ""} for i, label in enumerate(labels)],
                        "images": [],
                        "annotations": []
                    }
                    # Add image information (assuming 1 image per frame)
                    coco_data_per_frame[frame_num]["images"].append({
                        "id": frame_num,
                        "width": width,
                        "height": height,
                        "file_name": f"frame{frame_num:05d}.jpg",  # Use consistent naming
                    })

                # Add annotation
                coco_data_per_frame[frame_num]["annotations"].append({
                    "id": len(coco_data_per_frame[frame_num]["annotations"]) + 1,
                    "image_id": frame_num,
                    "category_id": label_id,
                    "bbox": [xtl, ytl, bbox_width, bbox_height],
                    "area": bbox_width * bbox_height,
                    "iscrowd": 0,
                    "attributes": attributes
                })

        # Save COCO data for each frame to separate files *within the subdirectory*
        for frame_num, coco_data in coco_data_per_frame.items():
            coco_filename = f"{os.path.splitext(cvat_file)[0]}_coco_frame{frame_num:05d}.json"
            coco_path = os.path.join(coco_subdir, coco_filename)  # Save in subdirectory

            # Check if COCO file already exists
            if os.path.exists(coco_path):
                print(f"COCO file {coco_filename} already exists. Skipping.")
                continue

            with open(coco_path, "w") as f:
                json.dump(coco_data, f, indent=4)
            print(f"Converted {cvat_file} (frame {frame_num}) to {coco_filename}")

# %% [markdown]
# ## Execution

# %%
if __name__ == "__main__":
    video_directory = "../data/video"
    frame_directory = "../data/frame"
    annotation_directory = "../data/annotation/cvat"
    coco_annotation_directory = "../data/annotation/coco"

    convert_video_to_frames(video_directory, frame_directory, annotation_directory)
    convert_cvat_to_coco(annotation_directory, coco_annotation_directory)
    print("Done!")
# Out:
# Frames extracted from video_001.mp4 to ../data/frame\video_001
# Frames extracted from video_002.mp4 to ../data/frame\video_002
# Frames extracted from video_003.mp4 to ../data/frame\video_003
# Frames extracted from video_004.mp4 to ../data/frame\video_004
# Frames extracted from video_005.mp4 to ../data/frame\video_005
# Frames extracted from video_006.mp4 to ../data/frame\video_006
# Frames extracted from video_007.mp4 to ../data/frame\video_007
# Frames extracted from video_008.mp4 to ../data/frame\video_008
# Frames extracted from video_009.mp4 to ../data/frame\video_009
# Frames extracted from video_010.mp4 to ../data/frame\video_010
# COCO file annotation_cvat_001_coco_frame00000.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00001.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00002.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00003.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00004.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00005.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00006.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00007.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00008.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00009.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00010.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00011.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00012.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00013.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00014.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00015.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00016.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00017.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00018.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00019.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00020.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00021.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00022.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00023.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00024.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00025.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00026.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00027.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00028.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00029.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00030.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00031.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00032.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00033.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00034.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00035.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00036.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00037.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00038.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00039.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00040.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00041.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00042.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00043.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00044.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00045.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00046.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00047.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00048.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00049.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00050.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00051.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00052.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00053.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00054.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00055.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00056.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00057.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00058.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00059.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00060.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00061.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00062.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00063.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00064.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00065.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00066.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00067.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00068.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00069.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00070.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00071.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00072.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00073.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00074.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00075.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00076.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00077.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00078.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00079.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00080.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00081.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00082.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00083.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00084.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00085.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00086.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00087.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00088.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00089.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00090.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00091.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00092.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00093.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00094.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00095.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00096.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00097.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00098.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00099.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00100.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00101.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00102.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00103.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00104.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00105.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00106.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00107.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00108.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00109.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00110.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00111.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00112.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00113.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00114.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00115.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00116.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00117.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00118.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00119.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00120.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00121.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00122.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00123.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00124.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00125.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00126.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00127.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00128.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00129.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00130.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00131.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00132.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00133.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00134.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00135.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00136.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00137.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00138.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00139.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00140.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00141.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00142.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00143.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00144.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00145.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00146.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00147.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00148.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00149.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00150.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00151.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00152.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00153.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00154.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00155.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00156.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00157.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00158.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00159.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00160.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00161.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00162.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00163.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00164.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00165.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00166.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00167.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00168.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00169.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00170.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00171.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00172.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00173.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00174.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00175.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00176.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00177.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00178.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00179.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00180.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00181.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00182.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00183.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00184.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00185.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00186.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00187.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00188.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00189.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00190.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00191.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00192.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00193.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00194.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00195.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00196.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00197.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00198.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00199.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00200.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00201.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00202.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00203.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00204.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00205.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00206.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00207.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00208.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00209.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00210.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00211.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00212.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00213.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00214.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00215.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00216.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00217.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00218.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00219.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00220.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00221.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00222.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00223.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00224.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00225.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00226.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00227.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00228.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00229.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00230.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00231.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00232.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00233.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00234.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00235.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00236.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00237.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00238.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00239.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00240.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00241.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00242.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00243.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00244.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00245.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00246.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00247.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00248.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00249.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00250.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00251.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00252.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00253.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00254.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00255.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00256.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00257.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00258.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00259.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00260.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00261.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00262.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00263.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00264.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00265.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00266.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00267.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00268.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00269.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00270.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00271.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00272.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00273.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00274.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00275.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00276.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00277.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00278.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00279.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00280.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00281.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00282.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00283.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00284.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00285.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00286.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00287.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00288.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00289.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00290.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00291.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00292.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00293.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00294.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00295.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00296.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00297.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00298.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00299.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00300.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00301.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00302.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00303.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00304.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00305.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00306.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00307.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00308.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00309.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00310.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00311.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00312.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00313.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00314.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00315.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00316.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00317.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00318.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00319.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00320.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00321.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00322.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00323.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00324.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00325.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00326.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00327.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00328.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00329.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00330.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00331.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00332.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00333.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00334.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00335.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00336.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00337.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00338.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00339.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00340.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00341.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00342.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00343.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00344.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00345.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00346.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00347.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00348.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00349.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00350.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00351.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00352.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00353.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00354.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00355.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00356.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00357.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00358.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00359.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00360.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00361.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00362.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00363.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00364.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00365.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00366.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00367.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00368.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00369.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00370.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00371.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00372.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00373.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00374.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00375.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00376.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00377.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00378.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00379.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00380.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00381.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00382.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00383.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00384.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00385.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00386.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00387.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00388.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00389.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00390.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00391.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00392.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00393.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00394.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00395.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00396.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00397.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00398.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00399.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00400.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00401.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00402.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00403.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00404.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00405.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00406.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00407.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00408.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00409.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00410.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00411.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00412.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00413.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00414.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00415.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00416.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00417.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00418.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00419.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00420.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00421.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00422.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00423.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00424.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00425.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00426.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00427.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00428.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00429.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00430.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00431.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00432.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00433.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00434.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00435.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00436.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00437.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00438.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00439.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00440.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00441.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00442.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00443.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00444.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00445.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00446.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00447.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00448.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00449.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00450.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00451.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00452.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00453.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00454.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00455.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00456.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00457.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00458.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00459.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00460.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00461.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00462.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00463.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00464.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00465.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00466.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00467.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00468.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00469.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00470.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00471.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00472.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00473.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00474.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00475.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00476.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00477.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00478.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00479.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00480.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00481.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00482.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00483.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00484.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00485.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00486.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00487.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00488.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00489.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00490.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00491.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00492.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00493.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00494.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00495.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00496.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00497.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00498.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00499.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00500.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00501.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00502.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00503.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00504.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00505.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00506.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00507.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00508.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00509.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00510.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00511.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00512.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00513.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00514.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00515.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00516.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00517.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00518.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00519.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00520.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00521.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00522.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00523.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00524.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00525.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00526.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00527.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00528.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00529.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00530.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00531.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00532.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00533.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00534.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00535.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00536.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00537.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00538.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00539.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00540.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00541.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00542.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00543.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00544.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00545.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00546.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00547.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00548.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00549.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00550.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00551.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00552.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00553.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00554.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00555.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00556.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00557.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00558.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00559.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00560.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00561.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00562.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00563.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00564.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00565.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00566.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00567.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00568.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00569.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00665.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00666.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00667.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00668.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00669.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00670.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00671.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00672.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00673.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00674.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00675.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00676.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00677.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00678.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00679.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00680.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00681.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00682.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00683.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00684.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00685.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00686.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00687.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00688.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00689.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00690.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00691.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00692.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00693.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00694.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00695.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00696.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00697.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00698.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00699.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00700.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00701.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00702.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00703.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00704.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00705.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00706.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00707.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00708.json already exists. Skipping.
# COCO file annotation_cvat_001_coco_frame00709.json already exists. Skipping.
# ...
# COCO file annotation_cvat_010_coco_frame01269.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01270.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01271.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01272.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01273.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01274.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01275.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01276.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01277.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01278.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01279.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01280.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01281.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01282.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01283.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01284.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01285.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01286.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01287.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01288.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01289.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01290.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01291.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01292.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01293.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01294.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01295.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01296.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01297.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01298.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01299.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01300.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01301.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01302.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01303.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01304.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01305.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01306.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01307.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01308.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01309.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01310.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01311.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01312.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01313.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01314.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01315.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01316.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01317.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01318.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01319.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01320.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01321.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01322.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01323.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01324.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01325.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01326.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01327.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01328.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01329.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01330.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01331.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01332.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01333.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01334.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01335.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01336.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01337.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01338.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01339.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01340.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01341.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01342.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01343.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01344.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01345.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01346.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01347.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01348.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01349.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01350.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01351.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01352.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01353.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01354.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01355.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01356.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01357.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01358.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01359.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01360.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01361.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01362.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01363.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01364.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01365.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01366.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01367.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01368.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01369.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01370.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01371.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01372.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01373.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01374.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01375.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01376.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01377.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01378.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01379.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01380.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01381.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01382.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01383.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01384.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01385.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01386.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01387.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01388.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01389.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01390.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01391.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01392.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01393.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01394.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01395.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01396.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01397.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01398.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01399.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01400.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01401.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01402.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01403.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01404.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01405.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01406.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01407.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01408.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01409.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01410.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01411.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01412.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01413.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01414.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01415.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01416.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01417.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01418.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01419.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01420.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01421.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01422.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01423.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01424.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01425.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01426.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01427.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01428.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01429.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01430.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01431.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01432.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01433.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01434.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01435.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01436.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01437.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01438.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01439.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01440.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01441.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01442.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01443.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01444.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01445.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01446.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01447.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01448.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01449.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01450.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01451.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01452.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01453.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01454.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01455.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01456.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01457.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01458.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01459.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01460.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01461.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01462.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01463.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01464.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01465.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01466.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01467.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01468.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01469.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01470.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01471.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01472.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01473.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01474.json already exists. Skipping.
# COCO file annotation_cvat_010_coco_frame01475.json already exists. Skipping.
# Done!
